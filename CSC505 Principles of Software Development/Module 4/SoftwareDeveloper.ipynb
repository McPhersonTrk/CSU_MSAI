# %%
#  OoDesign Builder Pattern
# https://www.oodesign.com/builder-pattern.html
# The Builder Pattern is a creational pattern defined by GoF in which an object is constructed
#  in a step-by-step manner.

# This pattern was chosen because it allows for the creation of complex objects with a simple
#  interface. The Builder Pattern is used to construct a complex object step by step and the final
# step will return the object. The process of constructing an object should be generic so that it
#  can be used to create different representations of the same object.

	 
'''
//Abstract Builder
class abstract class TextConverter{
	abstract void convertCharacter(char c);
	abstract void convertParagraph();
}

// Product
class ASCIIText{
	public void append(char c){ //Implement the code here }
}

//Concrete Builder
class ASCIIConverter extends TextConverter{
	ASCIIText asciiTextObj;//resulting product

	/*converts a character to target representation and appends to the resulting*/
	object void convertCharacter(char c){
		char asciiChar = new Character(c).charValue();
			//gets the ascii character
		asciiTextObj.append(asciiChar);
	}
	void convertParagraph(){}
	ASCIIText getResult(){
		return asciiTextObj;
	}
}

//This class abstracts the document object
class Document{
	static int value;
	char token;
	public char getNextToken(){
		//Get the next token
		return token;
	}
}

//Director
class RTFReader{
	private static final char EOF='0'; //Delimitor for End of File
	final char CHAR='c';
	final char PARA='p';
	char t;
	TextConverter builder;
	RTFReader(TextConverter obj){
		builder=obj;
	}
	void parseRTF(Document doc){
		while ((t=doc.getNextToken())!= EOF){
			switch (t){
				case CHAR: builder.convertCharacter(t);
				case PARA: builder.convertParagraph();
			}
		}
	}
}

//Client
public class Client{
	void createASCIIText(Document doc){
		ASCIIConverter asciiBuilder = new ASCIIConverter();
		RTFReader rtfReader = new RTFReader(asciiBuilder);
		rtfReader.parseRTF(doc);
		ASCIIText asciiText = asciiBuilder.getResult();
	}
	public static void main(String args[]){
		Client client=new Client();
		Document doc=new Document();
		client.createASCIIText(doc);
		system.out.println("This is an example of Builder Pattern");
	}
}
'''

# %%
# Define the sw_developer class
class sw_developer:
    def __init__(self):
        self.analytical_thinking = False
        self.problem_solving = False
        self.teamwork = False
        self.continuous_learning = False
        self.adaptability = False
        self.attention_to_detail = False
        self.creativity = False
        self.resilience = False
        self.dependability = False
        self.time_management = False
        self.leadership = False
        self.curiosity = False
        self.ethical = False
        self.gets_results = False

# Abstract Builder
class sw_developer_traits_builder:
    """
    Abstract Builder class that defines the interface for creating a software developer.
    """
    def __init__(self):
        self.reset()
    def reset(self):
        """
        Resets the builder's attributes to an empty sw_developer object.
        """
        self.developer = sw_developer()
    def analytical_thinking_add(self):
        self.developer.analytical_thinking = True
    def problem_solving_add(self):
        self.developer.problem_solving = True
    def teamwork_add(self):
        self.developer.teamwork = True
    def continuous_learning_add(self):
        self.developer.continuous_learning = True
    def adaptability_add(self):
        self.developer.adaptability = True
    def attention_to_detail_add(self):
        self.developer.attention_to_detail = True
    def creativity_add(self):
        self.developer.creativity = True
    def resilience_add(self):
        self.developer.resilience = True
    def dependability_add(self):
        self.developer.dependability = True
    def time_management_add(self):
        self.developer.time_management = True
    def leadership_add(self):
        self.developer.leadership = True
    def curiosity_add(self):
        self.developer.curiosity = True
    def ethical_add(self):
        self.developer.ethical = True
    def gets_results_add(self):
        self.developer.gets_results = True
    def get_result(self):
        """
        Returns a fully constructed sw_developer object.
        """
        result = self.developer
        self.reset()
        return result

# Concrete Builder
class sw_developer_concrete_builder(sw_developer_traits_builder):
    """
    Concrete Builder that implements methods to add specific traits to a
    sw_developer object.
    """
    pass  # No changes required; inherited methods are sufficient.

# Director
class sw_development_director:
    """
    Director class that orchestrates the construction process using the builder.
    """
    def __init__(self, builder):
        self.builder = builder
    def construct_full_developer(self):
        """
        Constructs a sw_developer by directing the builder to add all traits.
        """
        self.builder.analytical_thinking_add()
        self.builder.problem_solving_add()
        self.builder.teamwork_add()
        self.builder.continuous_learning_add()
        self.builder.adaptability_add()
        self.builder.attention_to_detail_add()
        self.builder.creativity_add()
        self.builder.resilience_add()
        self.builder.dependability_add()
        self.builder.time_management_add()
        self.builder.leadership_add()
        self.builder.curiosity_add()
        self.builder.ethical_add()
        self.builder.gets_results_add()

# Client Code
def main():
    # Instantiate the builder and director
    builder = sw_developer_concrete_builder()
    director = sw_development_director(builder)

    # Construct the sw_developer object with all traits
    director.construct_full_developer()
    developer = builder.get_result()

    # Display the developer's traits
    print("SW Developer Object:")
    print(f"Analytical Thinking: {developer.analytical_thinking}")
    print(f"Problem Solving: {developer.problem_solving}")
    print(f"Teamwork: {developer.teamwork}")
    print(f"Continuous Learning: {developer.continuous_learning}")
    print(f"Adaptability: {developer.adaptability}")
    print(f"Attention to Detail: {developer.attention_to_detail}")
    print(f"Creativity: {developer.creativity}")
    print(f"Resilience: {developer.resilience}")
    print(f"Dependability: {developer.dependability}")
    print(f"Time Management: {developer.time_management}")
    print(f"Leadership: {developer.leadership}")
    print(f"Curiosity: {developer.curiosity}")
    print(f"Ethical: {developer.ethical}")
    print(f"Results-Oriented: {developer.gets_results}")

# Call the main function
if __name__ == "__main__":
    main()

# %%
import logging
from abc import ABC, abstractmethod

# Configure logging for debugging and tracking execution
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")


# Abstract Builder Interface
class TraitsBuilder(ABC):
    @abstractmethod
    def adaptability_add(self):
        pass
    @abstractmethod
    def collaboration_add(self):
        pass
    @abstractmethod
    def problem_solving_add(self):
        pass
    @abstractmethod
    def get_result(self):
        pass

# Concrete Builder Class
class DeveloperTraitsBuilder(TraitsBuilder):
    def __init__(self):
        self.traits = []
    def adaptability_add(self):
        logging.info("Adding adaptability trait.")
        self.traits.append({
            "trait": "Adaptability",
            "description": "Ability to handle changing requirements and environments."})
        return self
    def collaboration_add(self):
        logging.info("Adding collaboration trait.")
        self.traits.append({
            "trait": "Collaboration",
            "description": "Strong teamwork and communication skills."})
        return self
    def problem_solving_add(self):
        logging.info("Adding problem-solving trait.")
        self.traits.append({
            "trait": "Problem-Solving",
            "description": "Analytical thinking and troubleshooting abilities."})
        return self
    def get_result(self):
        logging.info("Fetching all traits.")
        return self.traits

# Director Class to Orchestrate the Building Process
class TraitsDirector:
    def __init__(self, builder: TraitsBuilder):
        self.builder = builder

    def construct_developer_traits(self):
        logging.info("Starting trait construction process.")
        self.builder.adaptability_add().collaboration_add().problem_solving_add()

# Main Execution Program
if __name__ == "__main__":
    # Instantiate the Builder and Director
    logging.info("Instantiating the DeveloperTraitsBuilder.")
    builder = DeveloperTraitsBuilder()
    director = TraitsDirector(builder)

    # Build the traits
    logging.info("Constructing developer traits using the director.")
    director.construct_developer_traits()

    # Fetch and display the traits
    traits = builder.get_result()

    # Prints a detailed description of the program's functionality
    print("\n=== Software Developer Personality Traits ===")
    print("This program demonstrates the Builder Pattern to model three essential personality traits of excellent software developers.")
    print("Important Steps in the Program:")
    print("1. Define an Abstract Builder Interface to establish a contract for the builder methods.")
    print("2. Implement the Concrete Builder Class to provide specific behaviors for the traits.")
    print("3. Use a Director Class to manage the construction process.")
    print("4. Fetch and display the constructed traits with descriptions.\n")

    print("=== Developer Personality Traits ===")
    for i, trait in enumerate(traits, 1):
        print(f"{i}. {trait['trait']} - {trait['description']}")
# Out:
# 2025-01-19 20:33:27,884 - INFO - Instantiating the DeveloperTraitsBuilder.
# 2025-01-19 20:33:27,885 - INFO - Constructing developer traits using the director.
# 2025-01-19 20:33:27,886 - INFO - Starting trait construction process.
# 2025-01-19 20:33:27,887 - INFO - Adding adaptability trait.
# 2025-01-19 20:33:27,887 - INFO - Adding collaboration trait.
# 2025-01-19 20:33:27,888 - INFO - Adding problem-solving trait.
# 2025-01-19 20:33:27,889 - INFO - Fetching all traits.
# === Software Developer Personality Traits ===
# This program demonstrates the Builder Pattern to model three essential personality traits of excellent software developers.
# Important Steps in the Program:
# 1. Define an Abstract Builder Interface to establish a contract for the builder methods.
# 2. Implement the Concrete Builder Class to provide specific behaviors for the traits.
# 3. Use a Director Class to manage the construction process.
# 4. Fetch and display the constructed traits with descriptions.
#
# ...

# %%
# %pip install graphviz
from graphviz import Digraph

# Function to create UML diagram
def create_uml_diagram():
    uml = Digraph("UML Diagram for SoftwareDeveloper", format="png")
    uml.attr(rankdir="TB", size="8")

    # Define SoftwareDeveloper class
    uml.node(
        "SoftwareDeveloper",
        '''SoftwareDeveloper|
+ traits: list[str]\\l
---------------
+ show_traits()\\l''',
        shape="record",
    )
    # Define DeveloperTraitsBuilder class
    uml.node(
        "DeveloperTraitsBuilder",
        '''DeveloperTraitsBuilder (Abstract)|
+ developer: SoftwareDeveloper\\l
---------------
+ add_analytical_thinking()\\l
+ add_teamwork()\\l
+ add_continuous_learning()\\l
+ add_communication_skills()\\l
+ add_adaptability()\\l
+ add_attention_to_detail()\\l
+ add_creativity()\\l
+ add_resilience()\\l
+ add_dependability()\\l
+ add_time_management()\\l
+ add_leadership()\\l
+ add_curiosity()\\l
+ add_empathy()\\l
+ add_ethical_thinking()\\l
+ get_result()\\l''',
        shape="record",
    )

    # Define SoftwareDeveloperBuilder class
    uml.node(
        "SoftwareDeveloperBuilder",
        '''SoftwareDeveloperBuilder|
+ add_analytical_thinking()\\l
+ add_teamwork()\\l
+ add_continuous_learning()\\l
+ add_communication_skills()\\l
+ add_adaptability()\\l
+ add_attention_to_detail()\\l
+ add_creativity()\\l
+ add_resilience()\\l
+ add_dependability()\\l
+ add_time_management()\\l
+ add_leadership()\\l
+ add_curiosity()\\l
+ add_empathy()\\l
+ add_ethical_thinking()\\l
+ get_result()\\l''',
        shape="record",
    )
    # Define SoftwareDevelopmentDirector class
    uml.node(
        "SoftwareDevelopmentDirector",
        '''SoftwareDevelopmentDirector|
+ builder: DeveloperTraitsBuilder\\l
---------------
+ construct_full_developer()\\l''',
        shape="record",
    )
    # Relationships
    uml.edge("SoftwareDeveloperBuilder", "DeveloperTraitsBuilder", label="inherits")
    uml.edge("SoftwareDevelopmentDirector", "DeveloperTraitsBuilder", label="uses")
    uml.edge("DeveloperTraitsBuilder", "SoftwareDeveloper", label="creates")
    # Render the UML diagram
    uml_file = "C:/Users/mikea/Desktop/CSU-MSAI/CSU_MSAI_GitHub/CSC505 Principles of Software Development/Module 4/software_developer_uml"
    uml.render(uml_file, cleanup=True)
    return f"{uml_file}.png"

# Generate the corrected UML diagram
uml_diagram_path = create_uml_diagram()
uml_diagram_path
