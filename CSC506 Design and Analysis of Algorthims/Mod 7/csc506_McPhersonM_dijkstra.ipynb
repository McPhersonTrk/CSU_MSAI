# %% [markdown]
#  DijKstra Algorithm from zybooks:
#
#
#     # Define def dijkstra_shortest_path
#  def dijkstra_shortest_path(g, start_vertex):
#
#     # Put all vertices in an unvisited queue.
#     unvisited_queue = []
#     for current_vertex in g.adjacency_list:
#         unvisited_queue.append(current_vertex)
#
#     # start_vertex has a distance of 0 from itself
#     start_vertex.distance = 0
#
#     # One vertex is removed with each iteration; repeat until the list is
#     # empty.
#     while len(unvisited_queue) > 0:
#
#         # Visit vertex with minimum distance from start_vertex
#         smallest_index = 0
#         for i in range(1, len(unvisited_queue)):
#             if unvisited_queue[i].distance < unvisited_queue[smallest_index].distance:
#                 smallest_index = i
#         current_vertex = unvisited_queue.pop(smallest_index)
#
#         # Check potential path lengths from the current vertex to all neighbors.
#         for adj_vertex in g.adjacency_list[current_vertex]:
#             edge_weight = g.edge_weights[(current_vertex, adj_vertex)]
#             alternative_path_distance = current_vertex.distance + edge_weight
#
#             # If shorter path from start_vertex to adj_vertex is found,
#             # update adj_vertex's distance and predecessor
#             if alternative_path_distance < adj_vertex.distance:
#                 adj_vertex.distance = alternative_path_distance
#                 adj_vertex.pred_vertex = current_vertex

# %%
def dijkstra_shortest_path(g, start_vertex):
    # Put all vertices in an unvisited queue.
    unvisited_queue = []
    for current_vertex in g.adjacency_list:
        unvisited_queue.append(current_vertex)

    # start_vertex has a distance of 0 from itself
    start_vertex.distance = 0

    # One vertex is removed with each iteration; repeat until the list is
    # empty.
    while len(unvisited_queue) > 0:
        
        # Visit vertex with minimum distance from start_vertex
        smallest_index = 0
        for i in range(1, len(unvisited_queue)):
            if unvisited_queue[i].distance < unvisited_queue[smallest_index].distance:
                smallest_index = i
        current_vertex = unvisited_queue.pop(smallest_index)

        # Check potential path lengths from the current vertex to all neighbors.
        for adj_vertex in g.adjacency_list[current_vertex]:
            edge_weight = g.edge_weights[(current_vertex, adj_vertex)]
            alternative_path_distance = current_vertex.distance + edge_weight

            # If shorter path from start_vertex to adj_vertex is found,
            # update adj_vertex's distance and predecessor
            if alternative_path_distance < adj_vertex.distance:
                adj_vertex.distance = alternative_path_distance
                adj_vertex.pred_vertex = current_vertex

# %%
'''import heapq
import networkx as nx
import matplotlib.pyplot as plt

#Create a class for the delivery route
class DeliveryRoute:
    def __init__(self, start, end, distance):
        self.start = start
        self.end = end
        self.distance = distance
    #create a function that uses dijkstra's algorithm to find the shortest path
    def dijkstra(self, start, end):
        queue = []
        heapq.heappush(queue, (0, start))
        distances = {node:float('infinity') for node in self.graph.nodes}
        distances[start] = 0
        previous_nodes= {node: None for node in self.graph.nodes}
        # create a while loop to find the shortest path 
        while queue:
            current_distance, current_node= heapq.heappop(queue)
            #stop if we reach the end
            if current_node == end:
                break
            #check if the current node is in the graph
            for neighbor, weight in self.graph[current_node].items():
                distance = current_distance + weight['weight']
                #check if the distance is less than the distance of the neighbor
                if distance < distances[neighbor]:
                    distances[neighbor] = distance
                    heapq.heappush(queue, (distance, neighbor))
                    previous_nodes[neighbor] = current_node
        #return the shortest path and the distance            
        return self.__constructpath(previous_nodes, start, end), distance[end]
    #create a function to construct the path
    def __construct_path(self, previous_nodes, start, end):
        # create a list to store the path
        path = []
        # create a while loop to find the path
        while end is not None:
            path.append(end)
            end = previous_nodes[end]
        #return the path in reverse order    
        return path[::-1]
    #create a function to draw the graph
    def draw_graph(self):
        #create a graph
        self.graph = nx.Graph()
        #add the edges to the graph
        for edge in self.edges:
            self.graph.add_edge(edge[0], edge[1], weight = edge[2])
        #draw the graph
        nx.draw(self.graph, with_labels = True)
        plt.show()
# define the graph with traffic-weighted edges.
graph = nx.Graph()
graph.add_weighted_edges_from([('A', 'B', 3), ('A', 'C', 2), ('B', 'C', 1), ('B', 'D', 1), ('C', 'D', 2), ('D', 'E', 3), ('D', 'F', 1), ('E', 'F', 1)])
edges = graph.edges(data = True)

# create a delivery route object
route = DeliveryRoute(graph, edges)
shortest_path, distance = route.dijkstra('A', 'F')
print(f'The SHortest path from A to F is {shortest_path} with a distance of {distance}')
route.plot_graph(shortest_path) '''

# This notebook is broken. Starting over.
# Out:
# "import heapq\nimport networkx as nx\nimport matplotlib.pyplot as plt\n\n#Create a class for the delivery route\nclass DeliveryRoute:\n    def __init__(self, start, end, distance):\n        self.start = start\n        self.end = end\n        self.distance = distance\n    #create a function that uses dijkstra's algorithm to find the shortest path\n    def dijkstra(self, start, end):\n        queue = []\n        heapq.heappush(queue, (0, start))\n        distances = {node:float('infinity') for node in self.graph.nodes}\n        distances[start] = 0\n        previous_nodes= {node: None for node in self.graph.nodes}\n        # create a while loop to find the shortest path \n        while queue:\n            current_distance, current_node= heapq.heappop(queue)\n            #stop if we reach the end\n            if current_node == end:\n                break\n            #check if the current node is in the graph\n            for neighbor, weight in self.graph[current_node].items():\n     
# ...

# %%
import heapq
import networkx as nx
import matplotlib.pyplot as plt

# Create a class for the delivery route
class DeliveryRoute:
    def __init__(self, graph):
        self.graph = graph

    # Create a function that uses Dijkstra's algorithm to find the shortest path
    def dijkstra(self, start, end):
        queue = []
        heapq.heappush(queue, (0, start))
        distances = {node: float('inf') for node in self.graph.nodes}
        distances[start] = 0
        previous_nodes = {node: None for node in self.graph.nodes}

        # Create a while loop to find the shortest path 
        while queue:
            current_distance, current_node = heapq.heappop(queue)

            # Stop if we reach the end
            if current_node == end:
                break

            # Check if the current node is in the graph
            for neighbor, weight in self.graph[current_node].items():
                distance = current_distance + weight['weight']

                # Check if the distance is less than the distance of the neighbor
                if distance < distances[neighbor]:
                    distances[neighbor] = distance
                    heapq.heappush(queue, (distance, neighbor))
                    previous_nodes[neighbor] = current_node
        
        # Return the shortest path and the distance            
        return self.__construct_path(previous_nodes, start, end), distances[end]

    # Create a function to construct the path
    def __construct_path(self, previous_nodes, start, end):
        # Create a list to store the path
        path = []

        # Create a while loop to find the path
        while end is not None:
            path.append(end)
            end = previous_nodes[end]

        # Return the path in reverse order    
        return path[::-1]

    # Create a function to draw the graph
    def plot_graph(self, path=None):
        pos = nx.spring_layout(self.graph)
        labels = nx.get_edge_attributes(self.graph, 'weight')

        nx.draw(self.graph, pos, with_labels=True, node_color='lightblue', edge_color='gray')
        nx.draw_networkx_edge_labels(self.graph, pos, edge_labels=labels)

        if path:
            path_edges = list(zip(path, path[1:]))
            nx.draw_networkx_edges(self.graph, pos, edgelist=path_edges, edge_color='red', width=2)

        plt.show()
# Define the graph with traffic-weighted edges
graph = nx.Graph()
graph.add_weighted_edges_from([
    ('A', 'B', 3), ('A', 'C', 2), ('B', 'C', 1), ('B', 'D', 1),
    ('C', 'D', 2), ('D', 'E', 3), ('D', 'F', 1), ('E', 'F', 1)
])

# Create a delivery route object
route = DeliveryRoute(graph)
shortest_path, distance = route.dijkstra('A', 'F')

print(f'The shortest path from A to F is {shortest_path} with a distance of {distance}')
route.plot_graph(shortest_path)
# Out:
# The shortest path from A to F is ['A', 'C', 'D', 'F'] with a distance of 5

# %%
# Define the graph with locations and distances in Colorado Springs
colorado_springs_graph = nx.Graph()
colorado_springs_graph.add_weighted_edges_from([
    ('Location1', 'Location2', 5), 
    ('Location1', 'Location3', 10), 
    ('Location2', 'Location4', 3), 
    ('Location3', 'Location4', 1), 
    ('Location4', 'Location5', 8), 
    ('Location5', 'Location6', 2)
])

# Create a delivery route object for Colorado Springs
colorado_springs_route = DeliveryRoute(colorado_springs_graph)

# Find the shortest path from 'Location1' to 'Location6'
shortest_path_cs, distance_cs = colorado_springs_route.dijkstra('Location1', 'Location6')

print(f'The shortest path from Location1 to Location6 is {shortest_path_cs} with a distance of {distance_cs}')
colorado_springs_route.plot_graph(shortest_path_cs)
# Out:
# The shortest path from Location1 to Location6 is ['Location1', 'Location2', 'Location4', 'Location5', 'Location6'] with a distance of 18

# %%
# %pip install openrouteservice python-dotenv
# Out:
# ...
#   Obtaining dependency information for openrouteservice from https://files.pythonhosted.org/packages/67/1a/e6944e4cfd7c5386b15e4b4056084b3c8c676aca0a215d8b507a6cbc1263/openrouteservice-2.3.3-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## attempt at creating a route optimization in colorado springs using real data and OpenRouteService API calls.

# %%
import os
from dotenv import load_dotenv
import openrouteservice
import networkx as nx
import heapq

# Define your OpenRouteService API key
# Load environment variables from .env file
load_dotenv()

# Retrieve the API key
ORS_API_KEY = os.getenv("ORS_API_KEY")

# Check if the API key is loaded correctly
if not ORS_API_KEY:
    raise ValueError("Error: API Key not found. Please check your .env file.")

# Initialize the OpenRouteService client
client = openrouteservice.Client(key=ORS_API_KEY)

# Initialize the OpenRouteService client
client = openrouteservice.Client(key=ORS_API_KEY)

# Define the addresses and their coordinates
AmamzonStart = '4222 Integration Loop 1030 Colorado Springs CO 80916 '
del1 = '3200 BONNE VISTA DR COLORADO SPRINGS CO 80906-5845 USA'
del2 = '7600 TIMBERLINE CT COLORADO SPRINGS CO 80920-3744 USA'
del3 = '5360 BARNSTORMERS AVE COLORADO SPRINGS CO 80911-1277 USA'
AmazonEnd = '4222 Integration Loop 1030 Colorado Springs CO 80916'

locations = {
    'AmazonStart': (38.770094, -104.715538),  # Replace with actual coordinates
    'del1': (38.812884, -104.878093),  # Replace with actual coordinates
    'del2': (38.941731, -104.791249),  # Replace with actual coordinates
    'del3': (38.780562, -104.731392),  # Replace with actual coordinates
    'AmazonEnd': (38.770094, -104.715538),  # Replace with actual coordinates
}
### *** TEST API RESPONSE BEFORE FULL EXECUTION ***
test_coord1 = locations["AmazonStart"]
test_coord2 = locations["del1"]

try:
    print(f"Testing route between {test_coord1} and {test_coord2}...")
    routes = client.directions(
        coordinates=[test_coord1, test_coord2],
        profile='driving-car',
        format='geojson'
    )
    print("Route data received successfully!")
    print(routes)  # Prints the response to verify
except Exception as e:
    print(f"Error fetching test route: {e}")

# Function to get driving distance between two coordinates
def get_driving_distance(coord1, coord2):
    try:
        routes = client.directions(
            coordinates=[coord1, coord2], 
            profile='driving-car', 
            format='geojson', 
            radiuses=[10000, 10000]
        )
        distance = routes['features'][0]['properties']['segments'][0]['distance']  # Distance in meters
        return distance / 1000  # Convert to kilometers
    except Exception as e:
        print(f"Error fetching distance between {coord1} and {coord2}: {e}")
        return float('inf')

# Create a graph and add edges with driving distances as weights
graph = nx.Graph()
for loc1 in locations:
    for loc2 in locations:
        if loc1 != loc2:
            distance = get_driving_distance(locations[loc1], locations[loc2])
            graph.add_edge(loc1, loc2, weight=distance)

# Dijkstra's algorithm to find the shortest path
def dijkstra(graph, start):
    queue = []
    heapq.heappush(queue, (0, start))
    distances = {node: float('inf') for node in graph.nodes}
    distances[start] = 0
    previous_nodes = {node: None for node in graph.nodes}

    while queue:
        current_distance, current_node = heapq.heappop(queue)

        for neighbor in graph.neighbors(current_node):
            weight = graph[current_node][neighbor]['weight']
            distance = current_distance + weight

            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous_nodes[neighbor] = current_node
                heapq.heappush(queue, (distance, neighbor))

    return distances, previous_nodes

# Function to reconstruct the shortest path
def construct_path(previous_nodes, start, end):
    path = []
    current = end
    while current is not None:
        path.append(current)
        current = previous_nodes[current]
    path.reverse()
    return path

# Find the shortest path starting and ending at Amazon DC
start_point = 'AmazonStart'
distances, previous_nodes = dijkstra(graph, start_point)

# Since we need to return to the starting point, we look for the path that visits all nodes and returns
# This is a variation of the Traveling Salesman Problem (TSP), which is more complex than Dijkstra's algorithm
# For simplicity, we'll find the shortest path to visit all nodes and then return to the start

# Find the farthest node from the start to ensure all nodes are visited
farthest_node = max(distances, key=distances.get)

# Reconstruct the path from start to the farthest node
path = construct_path(previous_nodes, start_point, farthest_node)

# Add the return to the start point
path.append(start_point)

# Calculate the total distance of the path
total_distance = sum(graph[path[i]][path[i + 1]]['weight'] for i in range(len(path) - 1))

print(f"The optimal delivery route is: {' -> '.join(path)} with a total distance of {total_distance:.2f} km")
# Out:
# Testing route between (38.770094, -104.715538) and (38.812884, -104.878093)...
# Error fetching test route: 404 ({'error': {'code': 2010, 'message': 'Could not find routable point within a radius of 350.0 meters of specified coordinate 0: 38.7700940 -104.7155380.'}, 'info': {'engine': {'build_date': '2025-01-27T14:56:02Z', 'graph_version': '1', 'version': '9.0.0'}, 'timestamp': 1738534520918}})
# Error fetching distance between (38.770094, -104.715538) and (38.812884, -104.878093): 404 ({'error': {'code': 2010, 'message': 'Could not find routable point within a radius of 10000.0 meters of specified coordinate 0: 38.7700940 -104.7155380.'}, 'info': {'engine': {'build_date': '2025-01-27T14:56:02Z', 'graph_version': '1', 'version': '9.0.0'}, 'timestamp': 1738534521088}})
# ...

# %% [markdown]
# ## attempt at creating a route optimization in colorado springs using real data and Google maps API calls.

# %%
# %pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40750 sha256=9630c57e5b9b942f1b4c994c4d8c41ebe84cb8c35d3008c2b570b3f169439b3d
#   Stored in directory: c:\users\mikea\appdata\local\pip\cache\wheels\f1\09\77\3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

GMAPS_API_KEY = os.getenv("GMAPS_API_KEY")
print(f"Loaded API Key: {GMAPS_API_KEY}")
# Out:
# Loaded API Key: AIzaSyCA-r9FEr9ColNw7nRcQrsqTvzpsU0u2uU

# %%
import os
from dotenv import load_dotenv
import googlemaps
import networkx as nx
import heapq

# Load environment variables
load_dotenv()

# Retrieve Google Maps API key

API_KEY = os.getenv("GMAPS_API_KEY")
if not API_KEY:
    raise ValueError("Error: Google Maps API Key not found. Please check your .env file.")

# Initialize Google Maps client
gmaps = googlemaps.Client(key=API_KEY)

# Define the addresses
addresses = {
    'AmazonStart': '4222 Integration Loop 1030 Colorado Springs CO 80916',
    'del1': '3200 BONNE VISTA DR COLORADO SPRINGS CO 80906-5845 USA',
    'del2': '7600 TIMBERLINE CT COLORADO SPRINGS CO 80920-3744 USA',
    'del3': '5360 BARNSTORMERS AVE COLORADO SPRINGS CO 80911-1277 USA',
    'AmazonEnd': '4222 Integration Loop 1030 Colorado Springs CO 80916'
}

# Function to get driving distance between two addresses
def get_google_distance(address1, address2):
    try:
        result = gmaps.distance_matrix(address1, address2, mode="driving")
        distance = result["rows"][0]["elements"][0]["distance"]["value"] / 1000  # Convert meters to km
        return distance
    except Exception as e:
        print(f"Error fetching Google distance between {address1} and {address2}: {e}")
        return float('inf')

# Create a graph and add edges with driving distances as weights
graph = nx.Graph()
for loc1 in addresses:
    for loc2 in addresses:
        if loc1 != loc2:
            distance = get_google_distance(addresses[loc1], addresses[loc2])
            graph.add_edge(loc1, loc2, weight=distance)

# Dijkstra's algorithm to find the shortest path
def dijkstra(graph, start):
    queue = []
    heapq.heappush(queue, (0, start))
    distances = {node: float('inf') for node in graph.nodes}
    distances[start] = 0
    previous_nodes = {node: None for node in graph.nodes}

    while queue:
        current_distance, current_node = heapq.heappop(queue)

        for neighbor in graph.neighbors(current_node):
            weight = graph[current_node][neighbor]['weight']
            distance = current_distance + weight

            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous_nodes[neighbor] = current_node
                heapq.heappush(queue, (distance, neighbor))

    return distances, previous_nodes

# Function to reconstruct the shortest path
def construct_path(previous_nodes, start, end):
    path = []
    current = end
    while current is not None:
        path.append(current)
        current = previous_nodes[current]
    path.reverse()
    return path

# Find the shortest path starting and ending at Amazon DC
start_point = 'AmazonStart'
distances, previous_nodes = dijkstra(graph, start_point)

# Find the farthest node from the start to ensure all nodes are visited
farthest_node = max(distances, key=distances.get)

# Reconstruct the path from start to the farthest node
path = construct_path(previous_nodes, start_point, farthest_node)

# Add the return to the start point
path.append(start_point)

# Calculate the total distance of the path
total_distance = sum(graph[path[i]][path[i + 1]]['weight'] for i in range(len(path) - 1))

print(f"The optimal delivery route is: {' -> '.join(path)} with a total distance of {total_distance:.2f} km")
# Out:
# The optimal delivery route is: AmazonStart -> del2 -> AmazonStart with a total distance of 56.04 km

# %% [markdown]
# ## At this point I discovered Dijkstra wall less than optimal at multi-stop delivery optimization.-- end assignment.

# %% [markdown]
# # Route Optimization Beyond Dijkstra's Algorithm
#
# ## Background
# After completing the implementation of **Dijkstra’s Algorithm** for basic shortest-path calculations, I found myself intrigued by the real-world applications of **route optimization** in logistics. With **20 years of experience in the logistics industry**, I realized that while Dijkstra’s algorithm is effective for shortest-path problems, it **does not account for multi-stop route efficiency**, a critical factor in delivery operations.
#
# ## Exploring Advanced Optimization Techniques
# To optimize the delivery route further, I researched and implemented the following improvements:
#
# ### 1. **Traveling Salesman Problem (TSP) for Route Optimization**
# - Since the task involved **visiting multiple delivery locations** before returning to the starting point, **Dijkstra’s algorithm was insufficient**.
# - Instead, I implemented **a brute-force TSP solver using permutations**, which evaluated every possible route combination and selected the one with the shortest total distance.
# - This method ensured **all delivery stops were covered efficiently**, optimizing time and fuel costs.
#
# ### 2. **Google Maps API for Real-World Road Distances**
# - Instead of using **direct geographical distances**, I integrated **Google Maps Distance Matrix API** to fetch actual **road-based travel distances**.
# - This allowed for **realistic distance and time calculations**, accounting for road layouts and driving conditions.
# - Implemented caching (`distance_cache.json`) to **reduce redundant API calls and improve performance**.
#
# ### 3. **Generating Realistic Driving Routes with Google Directions API**
# - Straight-line connections between stops **don’t reflect real-world driving routes**, so I incorporated the **Google Directions API**.
# - This allowed me to generate **turn-by-turn navigation paths** and **polyline-encoded routes** following actual roads.
# - The final output provided a **visually accurate and real-world applicable route**.
#
# ### 4. **Enhanced Map Visualization with Folium**
# - Instead of **basic plotted points**, I created an **interactive map** using `folium`, which includes:
#   - **Color-coded markers** (Green for start, Red for end, Blue for delivery stops).
#   - **Clickable labels** displaying delivery addresses.
#   - **Road-following polylines** for clarity in routing.
# - The map is automatically saved as `optimized_route_map.html` for **easy viewing in any browser**.
#
# ### 5. **Incorporating Estimated Travel Time**
# - Pulled estimated **real-time driving durations** from Google Maps.
# - Displayed **segment-by-segment travel time** in the console for improved **route planning insights**.
# - Provided a **total estimated delivery duration** at the end of execution.
#
# ## Summary & Future Enhancements
# This optimization project **transformed a basic shortest-path problem** into a **real-world logistics solution**. By incorporating **TSP, real road distances, API integrations, and interactive mapping**, I developed a **functional route optimization model**.
#
# ### Future Improvements:
# - **Dynamic Traffic Consideration:** Integrate real-time traffic data for adaptive routing.
# - **Machine Learning Optimization:** Use AI-driven models to predict delivery times.
# - **Multi-Vehicle Routing:** Expand the system for **fleet-level optimization**.
#
# 🚀 This deep dive into **route optimization** provided valuable insights into the **intersection of logistics, technology, and real-world efficiency**. Let me know if you’d like to explore further enhancements! 🚚📍

# %%
import os
from dotenv import load_dotenv
import googlemaps
import networkx as nx
from itertools import permutations

# Load environment variables
load_dotenv()

# Retrieve Google Maps API key
GMAPS_API_KEY = os.getenv("GMAPS_API_KEY")
if not GMAPS_API_KEY:
    raise ValueError("Error: Google Maps API Key not found. Please check your .env file.")

# Initialize Google Maps client
gmaps = googlemaps.Client(key=GMAPS_API_KEY)

# Define the addresses
addresses = {
    'AmazonStart': '4222 Integration Loop 1030 Colorado Springs CO 80916',
    'del1': '3200 BONNE VISTA DR COLORADO SPRINGS CO 80906-5845 USA',
    'del2': '7600 TIMBERLINE CT COLORADO SPRINGS CO 80920-3744 USA',
    'del3': '5360 BARNSTORMERS AVE COLORADO SPRINGS CO 80911-1277 USA',
    'AmazonEnd': '4222 Integration Loop 1030 Colorado Springs CO 80916'
}

# Function to get driving distance between two addresses
def get_google_distance(address1, address2):
    try:
        result = gmaps.distance_matrix(address1, address2, mode="driving")
        distance = result["rows"][0]["elements"][0]["distance"]["value"] / 1000  # Convert meters to km
        return distance
    except Exception as e:
        print(f"🚨 API ERROR: {e} (Addresses: {address1} -> {address2})")
        return float('inf')

# Create a graph with distances as edge weights
graph = {}
for loc1 in addresses:
    for loc2 in addresses:
        if loc1 != loc2:
            graph[(loc1, loc2)] = get_google_distance(addresses[loc1], addresses[loc2])

# Function to solve TSP using brute-force permutations
def tsp_bruteforce(graph, start, waypoints, end):
    min_distance = float('inf')
    best_route = None
    
    for perm in permutations(waypoints):
        route = [start] + list(perm) + [end]
        total_distance = sum(graph[(route[i], route[i+1])] for i in range(len(route)-1))
        
        if total_distance < min_distance:
            min_distance = total_distance
            best_route = route
            
    return best_route, min_distance

# Define waypoints (delivery addresses)
waypoints = ['del1', 'del2', 'del3']

# Find the optimal delivery route using TSP
optimal_route, optimal_distance = tsp_bruteforce(graph, 'AmazonStart', waypoints, 'AmazonEnd')

# Display results
print(f"\n🚚 The optimal delivery route is: {' → '.join(optimal_route)}")
print(f"📏 Total Distance: {optimal_distance:.2f} km")
# Out:
# 🚚 The optimal delivery route is: AmazonStart → del3 → del1 → del2 → AmazonEnd
# 📏 Total Distance: 81.13 km

# %% [markdown]
# #### impliment casching to avoid API calls.

# %%
import os
from dotenv import load_dotenv
import googlemaps
import networkx as nx
from itertools import permutations
import json

# Load environment variables
load_dotenv()

# Retrieve Google Maps API key
GMAPS_API_KEY = os.getenv("GMAPS_API_KEY")
if not GMAPS_API_KEY:
    raise ValueError("Error: Google Maps API Key not found. Please check your .env file.")

# Initialize Google Maps client
gmaps = googlemaps.Client(key=GMAPS_API_KEY)

# Define the addresses
addresses = {
    'AmazonStart': '4222 Integration Loop 1030 Colorado Springs CO 80916',
    'del1': '3200 BONNE VISTA DR COLORADO SPRINGS CO 80906-5845 USA',
    'del2': '7600 TIMBERLINE CT COLORADO SPRINGS CO 80920-3744 USA',
    'del3': '5360 BARNSTORMERS AVE COLORADO SPRINGS CO 80911-1277 USA',
    'AmazonEnd': '4222 Integration Loop 1030 Colorado Springs CO 80916'
}

# Load cached distances
CACHE_FILE = "distance_cache.json"
if os.path.exists(CACHE_FILE):
    with open(CACHE_FILE, "r") as f:
        distance_cache = json.load(f)
else:
    distance_cache = {}

# Function to get driving distance between two addresses with caching
def get_google_distance(address1, address2):
    key = f"{address1} -> {address2}"
    reverse_key = f"{address2} -> {address1}"
    
    if key in distance_cache:
        return distance_cache[key]
    if reverse_key in distance_cache:
        return distance_cache[reverse_key]
    
    try:
        result = gmaps.distance_matrix(address1, address2, mode="driving")
        distance = result["rows"][0]["elements"][0]["distance"]["value"] / 1000  # Convert meters to km
        
        # Cache the result
        distance_cache[key] = distance
        distance_cache[reverse_key] = distance
        with open(CACHE_FILE, "w") as f:
            json.dump(distance_cache, f)
        
        return distance
    except Exception as e:
        print(f"🚨 API ERROR: {e} (Addresses: {address1} -> {address2})")
        return float('inf')

# Create a graph with distances as edge weights
graph = {}
for loc1 in addresses:
    for loc2 in addresses:
        if loc1 != loc2:
            graph[(loc1, loc2)] = get_google_distance(addresses[loc1], addresses[loc2])

# Function to solve TSP using brute-force permutations
def tsp_bruteforce(graph, start, waypoints, end):
    min_distance = float('inf')
    best_route = None
    
    for perm in permutations(waypoints):
        route = [start] + list(perm) + [end]
        total_distance = sum(graph[(route[i], route[i+1])] for i in range(len(route)-1))
        
        if total_distance < min_distance:
            min_distance = total_distance
            best_route = route
            
    return best_route, min_distance

# Define waypoints (delivery addresses)
waypoints = ['del1', 'del2', 'del3']

# Find the optimal delivery route using TSP
optimal_route, optimal_distance = tsp_bruteforce(graph, 'AmazonStart', waypoints, 'AmazonEnd')

# Display results
print(f"\n🚚 The optimal delivery route is: {' → '.join(optimal_route)}")
print(f"📏 Total Distance: {optimal_distance:.2f} km")
# Out:
# 🚚 The optimal delivery route is: AmazonStart → del2 → del1 → del3 → AmazonEnd
# 📏 Total Distance: 86.56 km

# %% [markdown]
# #### Adding a route map output

# %%
import os
from dotenv import load_dotenv
import googlemaps
import networkx as nx
from itertools import permutations
import json
import folium

# Load environment variables
load_dotenv()

# Retrieve Google Maps API key
GMAPS_API_KEY = os.getenv("GMAPS_API_KEY")
if not GMAPS_API_KEY:
    raise ValueError("Error: Google Maps API Key not found. Please check your .env file.")

# Initialize Google Maps client
gmaps = googlemaps.Client(key=GMAPS_API_KEY)

# Define the addresses
addresses = {
    'AmazonStart': '4222 Integration Loop 1030 Colorado Springs CO 80916',
    'del1': '3200 BONNE VISTA DR COLORADO SPRINGS CO 80906-5845 USA',
    'del2': '7600 TIMBERLINE CT COLORADO SPRINGS CO 80920-3744 USA',
    'del3': '5360 BARNSTORMERS AVE COLORADO SPRINGS CO 80911-1277 USA',
    'AmazonEnd': '4222 Integration Loop 1030 Colorado Springs CO 80916'
}

# Load cached distances
CACHE_FILE = "distance_cache.json"
if os.path.exists(CACHE_FILE):
    with open(CACHE_FILE, "r") as f:
        distance_cache = json.load(f)
else:
    distance_cache = {}

# Function to get driving distance between two addresses with caching
def get_google_distance(address1, address2):
    key = f"{address1} -> {address2}"
    reverse_key = f"{address2} -> {address1}"
    
    if key in distance_cache:
        return distance_cache[key]
    if reverse_key in distance_cache:
        return distance_cache[reverse_key]
    
    try:
        result = gmaps.distance_matrix(address1, address2, mode="driving")
        distance = result["rows"][0]["elements"][0]["distance"]["value"] / 1000  # Convert meters to km
        
        # Cache the result
        distance_cache[key] = distance
        distance_cache[reverse_key] = distance
        with open(CACHE_FILE, "w") as f:
            json.dump(distance_cache, f)
        
        return distance
    except Exception as e:
        print(f"🚨 API ERROR: {e} (Addresses: {address1} -> {address2})")
        return float('inf')

# Create a graph with distances as edge weights
graph = {}
for loc1 in addresses:
    for loc2 in addresses:
        if loc1 != loc2:
            graph[(loc1, loc2)] = get_google_distance(addresses[loc1], addresses[loc2])

# Function to solve TSP using brute-force permutations
def tsp_bruteforce(graph, start, waypoints, end):
    min_distance = float('inf')
    best_route = None
    
    for perm in permutations(waypoints):
        route = [start] + list(perm) + [end]
        total_distance = sum(graph[(route[i], route[i+1])] for i in range(len(route)-1))
        
        if total_distance < min_distance:
            min_distance = total_distance
            best_route = route
            
    return best_route, min_distance

# Define waypoints (delivery addresses)
waypoints = ['del1', 'del2', 'del3']

# Find the optimal delivery route using TSP
optimal_route, optimal_distance = tsp_bruteforce(graph, 'AmazonStart', waypoints, 'AmazonEnd')

# Generate map with route
map_center = gmaps.geocode(addresses['AmazonStart'])[0]['geometry']['location']
route_map = folium.Map(location=[map_center['lat'], map_center['lng']], zoom_start=12)

# Plot each location on the map
for loc in optimal_route:
    location_data = gmaps.geocode(addresses[loc])[0]['geometry']['location']
    folium.Marker([location_data['lat'], location_data['lng']], popup=loc).add_to(route_map)

# Draw the route lines
for i in range(len(optimal_route) - 1):
    loc1_data = gmaps.geocode(addresses[optimal_route[i]])[0]['geometry']['location']
    loc2_data = gmaps.geocode(addresses[optimal_route[i + 1]])[0]['geometry']['location']
    folium.PolyLine([(loc1_data['lat'], loc1_data['lng']), (loc2_data['lat'], loc2_data['lng'])], color='blue', weight=5).add_to(route_map)

# Save map to an HTML file
route_map.save("optimal_route_map.html")

# Display results
print(f"\n🚚 The optimal delivery route is: {' → '.join(optimal_route)}")
print(f"📏 Total Distance: {optimal_distance:.2f} km")
print("📍 Route map saved as 'optimal_route_map.html'. Open it in a browser to view.")
# Out:
# 🚚 The optimal delivery route is: AmazonStart → del2 → del1 → del3 → AmazonEnd
# 📏 Total Distance: 86.56 km
# 📍 Route map saved as 'optimal_route_map.html'. Open it in a browser to view.

# %% [markdown]
# ### adding adresses to the pins, adding actual road routes to the map.

# %%
import os
from dotenv import load_dotenv
import googlemaps
import folium
import json

# Load environment variables
load_dotenv()

# Retrieve Google Maps API key
GMAPS_API_KEY = os.getenv("GMAPS_API_KEY")
if not GMAPS_API_KEY:
    raise ValueError("Error: Google Maps API Key not found. Please check your .env file.")

# Initialize Google Maps client
gmaps = googlemaps.Client(key=GMAPS_API_KEY)

# Define delivery locations
addresses = {
    'AmazonStart': '4222 Integration Loop 1030 Colorado Springs CO 80916',
    'del1': '3200 BONNE VISTA DR COLORADO SPRINGS CO 80906-5845 USA',
    'del2': '7600 TIMBERLINE CT COLORADO SPRINGS CO 80920-3744 USA',
    'del3': '5360 BARNSTORMERS AVE COLORADO SPRINGS CO 80911-1277 USA',
    'AmazonEnd': '4222 Integration Loop 1030 Colorado Springs CO 80916'
}

# Load cached distances
CACHE_FILE = "distance_cache.json"
if os.path.exists(CACHE_FILE):
    with open(CACHE_FILE, "r") as f:
        distance_cache = json.load(f)
else:
    distance_cache = {}

# Function to get road-based route using Google Maps Directions API
def get_google_route(origin, destination):
    try:
        route = gmaps.directions(origin, destination, mode="driving")
        if route:
            return [(step['start_location']['lat'], step['start_location']['lng']) for leg in route for step in leg['legs'][0]['steps']] + [
                (route[0]['legs'][0]['end_location']['lat'], route[0]['legs'][0]['end_location']['lng'])]
    except Exception as e:
        print(f"🚨 API ERROR: {e} (Route: {origin} -> {destination})")
    return []

# Generate optimized route order (Assuming you've run TSP optimization)
optimal_route = ['AmazonStart', 'del3', 'del1', 'del2', 'AmazonEnd']

# Get map center based on the start location
map_center = gmaps.geocode(addresses['AmazonStart'])[0]['geometry']['location']
route_map = folium.Map(location=[map_center['lat'], map_center['lng']], zoom_start=12)

# Add markers with delivery address labels
for loc in optimal_route:
    location_data = gmaps.geocode(addresses[loc])[0]['geometry']['location']
    folium.Marker(
        [location_data['lat'], location_data['lng']],
        popup=addresses[loc],  # Display the address on click
        tooltip=loc,  # Hover label
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(route_map)

# Draw actual road-based routes
for i in range(len(optimal_route) - 1):
    loc1 = addresses[optimal_route[i]]
    loc2 = addresses[optimal_route[i + 1]]
    road_path = get_google_route(loc1, loc2)
    
    if road_path:
        folium.PolyLine(road_path, color='blue', weight=5, opacity=0.7).add_to(route_map)

# Save and display the map
route_map.save("optimized_route_map.html")
print("📍 Optimized route map saved as 'optimized_route_map.html'. Open it in a browser to view.")
# Out:
# 📍 Optimized route map saved as 'optimized_route_map.html'. Open it in a browser to view.

# %% [markdown]
# #### Final touches, added travel report, marker colors, map labels

# %%
import os
from dotenv import load_dotenv
import googlemaps
import folium
import json

# Load environment variables
load_dotenv()

# Retrieve Google Maps API key
GMAPS_API_KEY = os.getenv("GMAPS_API_KEY")
if not GMAPS_API_KEY:
    raise ValueError("Error: Google Maps API Key not found. Please check your .env file.")

# Initialize Google Maps client
gmaps = googlemaps.Client(key=GMAPS_API_KEY)

# Define delivery locations
addresses = {
    'AmazonStart': '4222 Integration Loop 1030 Colorado Springs CO 80916',
    'del1': '3200 BONNE VISTA DR COLORADO SPRINGS CO 80906-5845 USA',
    'del2': '7600 TIMBERLINE CT COLORADO SPRINGS CO 80920-3744 USA',
    'del3': '5360 BARNSTORMERS AVE COLORADO SPRINGS CO 80911-1277 USA',
    'AmazonEnd': '4222 Integration Loop 1030 Colorado Springs CO 80916'
}

# Load cached distances
CACHE_FILE = "distance_cache.json"
if os.path.exists(CACHE_FILE):
    with open(CACHE_FILE, "r") as f:
        distance_cache = json.load(f)
else:
    distance_cache = {}

# Function to get road-based route and estimated travel time using Google Maps Directions API
def get_google_route(origin, destination):
    try:
        route = gmaps.directions(origin, destination, mode="driving")
        if route:
            path = [(step['start_location']['lat'], step['start_location']['lng']) for leg in route for step in leg['legs'][0]['steps']] + [
                (route[0]['legs'][0]['end_location']['lat'], route[0]['legs'][0]['end_location']['lng'])]
            duration = route[0]['legs'][0]['duration']['text']  # Travel time
            return path, duration
    except Exception as e:
        print(f"🚨 API ERROR: {e} (Route: {origin} -> {destination})")
    return [], "N/A"

# Generate optimized route order (Assuming you've run TSP optimization)
optimal_route = ['AmazonStart', 'del3', 'del1', 'del2', 'AmazonEnd']

# Get map center based on the start location
map_center = gmaps.geocode(addresses['AmazonStart'])[0]['geometry']['location']
route_map = folium.Map(location=[map_center['lat'], map_center['lng']], zoom_start=12)

# Define marker colors
marker_colors = {
    'AmazonStart': 'green',
    'AmazonEnd': 'red',
    'del1': 'blue',
    'del2': 'blue',
    'del3': 'blue'
}

# Add markers with delivery address labels and color coding
for loc in optimal_route:
    location_data = gmaps.geocode(addresses[loc])[0]['geometry']['location']
    folium.Marker(
        [location_data['lat'], location_data['lng']],
        popup=f"{loc} - {addresses[loc]}",  # Display name and address on click
        tooltip=loc,  # Hover label
        icon=folium.Icon(color=marker_colors[loc], icon="info-sign")
    ).add_to(route_map)

# Draw actual road-based routes and track travel times
travel_summary = []
total_time = 0
for i in range(len(optimal_route) - 1):
    loc1 = addresses[optimal_route[i]]
    loc2 = addresses[optimal_route[i + 1]]
    road_path, travel_time = get_google_route(loc1, loc2)
    
    if road_path:
        folium.PolyLine(road_path, color='blue', weight=5, opacity=0.7).add_to(route_map)
        travel_summary.append(f"{optimal_route[i]} → {optimal_route[i+1]}: {travel_time}")

# Save and display the map
route_map.save("optimized_route_map.html")

# Print travel summary
print("\n🚚 The optimized delivery route:")
for summary in travel_summary:
    print(summary)
print(f"📏 Total Estimated Travel Time: {total_time} mins")
print("📍 Route map saved as 'optimized_route_map.html'. Open it in a browser to view.")
# Out:
# 🚚 The optimized delivery route:
# AmazonStart → del3: 9 mins
# del3 → del1: 23 mins
# del1 → del2: 24 mins
# del2 → AmazonEnd: 31 mins
# 📏 Total Estimated Travel Time: 0 mins
# 📍 Route map saved as 'optimized_route_map.html'. Open it in a browser to view.
